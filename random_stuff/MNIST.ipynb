# %% [markdown]
# # MNIST digit recognition - First attempt

# %% [markdown]
# ## Preparation

# %%
from fastai.vision.all import *
from fastbook import *

matplotlib.rc('image', cmap="Greys")

# %% [markdown]
# Download and unpack the MNIST digit dataset

# %%
path = untar_data(URLs.MNIST)
Path.BASE_PATH = path

# %% [markdown]
# #### Take a look inside the directory and create a list of all number paths

# %%
(path/"training").ls()
# Out:
# (#10) [Path('training/6'),Path('training/1'),Path('training/9'),Path('training/8'),Path('training/7'),Path('training/2'),Path('training/4'),Path('training/3'),Path('training/5'),Path('training/0')]

# %%
number_list = [(path/"training"/str(i)).ls().sorted() for i in range(10)]
vnumber_list = [(path/"testing"/str(i)).ls().sorted() for i in range(10)]

# %% [markdown]
# Look at a sample image

# %%
im3_path = number_list[3][1] 
im3 = Image.open(im3_path)
im3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=28x28 at 0x7F009BBC41C0>

# %% [markdown]
# #### Show as a Pandas DataFrame

# %%
im3_t = tensor(im3)
df = pd.DataFrame(im3_t)
df.style.set_properties(**{"font-size":"6pt"}).background_gradient("Greys")
# Out:
# <style type="text/css">
# #T_06b7b_row0_col0, #T_06b7b_row0_col1, #T_06b7b_row0_col2, #T_06b7b_row0_col3, #T_06b7b_row0_col4, #T_06b7b_row0_col5, #T_06b7b_row0_col6, #T_06b7b_row0_col7, #T_06b7b_row0_col8, #T_06b7b_row0_col9, #T_06b7b_row0_col10, #T_06b7b_row0_col11, #T_06b7b_row0_col12, #T_06b7b_row0_col13, #T_06b7b_row0_col14, #T_06b7b_row0_col15, #T_06b7b_row0_col16, #T_06b7b_row0_col17, #T_06b7b_row0_col18, #T_06b7b_row0_col19, #T_06b7b_row0_col20, #T_06b7b_row0_col21, #T_06b7b_row0_col22, #T_06b7b_row0_col23, #T_06b7b_row0_col24, #T_06b7b_row0_col25, #T_06b7b_row0_col26, #T_06b7b_row0_col27, #T_06b7b_row1_col0, #T_06b7b_row1_col1, #T_06b7b_row1_col2, #T_06b7b_row1_col3, #T_06b7b_row1_col4, #T_06b7b_row1_col5, #T_06b7b_row1_col6, #T_06b7b_row1_col7, #T_06b7b_row1_col8, #T_06b7b_row1_col9, #T_06b7b_row1_col10, #T_06b7b_row1_col11, #T_06b7b_row1_col12, #T_06b7b_row1_col13, #T_06b7b_row1_col14, #T_06b7b_row1_col15, #T_06b7b_row1_col16, #T_06b7b_row1_col17, #T_06b7b_row1_col18, #T_06b7b_row1_col19, #T_06b7b_row1_col20, #T_06b7b_row1_col21, #T_06b7b_row1_col22, #T_06b7b_row1_col23, #T_06b7b_row1_col24, #T_06b7b_row1_col25, #T_06b7b_row1_col26, #T_06b7b_row1_col27, #T_06b7b_row2_col0, #T_06b7b_row2_col1, #T_06b7b_row2_col2, #T_06b7b_row2_col3, #T_06b7b_row2_col4, #T_06b7b_row2_col5, #T_06b7b_row2_col6, #T_06b7b_row2_col7, #T_06b7b_row2_col8, #T_06b7b_row2_col9, #T_06b7b_row2_col10, #T_06b7b_row2_col11, #T_06b7b_row2_col12, #T_06b7b_row2_col13, #T_06b7b_row2_col14, #T_06b7b_row2_col15, #T_06b7b_row2_col16, #T_06b7b_row2_col17, #T_06b7b_row2_col18, #T_06b7b_row2_col19, #T_06b7b_row2_col20, #T_06b7b_row2_col21, #T_06b7b_row2_col22, #T_06b7b_row2_col23, #T_06b7b_row2_col24, #T_06b7b_row2_col25, #T_06b7b_row2_col26, #T_06b7b_row2_col27, #T_06b7b_row3_col0, #T_06b7b_row3_col1, #T_06b7b_row3_col2, #T_06b7b_row3_col3, #T_06b7b_row3_col4, #T_06b7b_row3_col5, #T_06b7b_row3_col6, #T_06b7b_row3_col7, #T_06b7b_row3_col8, #T_06b7b_row3_col9, #T_06b7b_row3_col10, #T_06b7b_row3_col11, #T_06b7b_row3_col12, #T_06b7b_row3_col13, #T_06b7b_row3_col14, #T_06b7b_row3_col15, #T_06b7b_row3_col16, #T_06b7b_row3_col17, #T_06b7b_row3_col18, #T_06b7b_row3_col19, #T_06b7b_row3_col20, #T_06b7b_row3_col21, #T_06b7b_row3_col22, #T_06b7b_row3_col23, #T_06b7b_row3_col24, #T_06b7b_row3_col25, #T_06b7b_row3_col26, #T_06b7b_row3_col27, #T_06b7b_row4_col0, #T_06b7b_row4_col1, #T_06b7b_row4_col2, #T_06b7b_row4_col3, #T_06b7b_row4_col4, #T_06b7b_row4_col5, #T_06b7b_row4_col6, #T_06b7b_row4_col7, #T_06b7b_row4_col8, #T_06b7b_row4_col9, #T_06b7b_row4_col10, #T_06b7b_row4_col11, #T_06b7b_row4_col12, #T_06b7b_row4_col13, #T_06b7b_row4_col14, #T_06b7b_row4_col15, #T_06b7b_row4_col16, #T_06b7b_row4_col17, #T_06b7b_row4_col18, #T_06b7b_row4_col19, #T_06b7b_row4_col20, #T_06b7b_row4_col21, #T_06b7b_row4_col22, #T_06b7b_row4_col23, #T_06b7b_row4_col24, #T_06b7b_row4_col25, #T_06b7b_row4_col26, #T_06b7b_row4_col27, #T_06b7b_row5_col0, #T_06b7b_row5_col1, #T_06b7b_row5_col2, #T_06b7b_row5_col3, #T_06b7b_row5_col4, #T_06b7b_row5_col5, #T_06b7b_row5_col6, #T_06b7b_row5_col7, #T_06b7b_row5_col8, #T_06b7b_row5_col19, #T_06b7b_row5_col20, #T_06b7b_row5_col21, #T_06b7b_row5_col22, #T_06b7b_row5_col23, #T_06b7b_row5_col24, #T_06b7b_row5_col25, #T_06b7b_row5_col26, #T_06b7b_row5_col27, #T_06b7b_row6_col0, #T_06b7b_row6_col1, #T_06b7b_row6_col2, #T_06b7b_row6_col3, #T_06b7b_row6_col4, #T_06b7b_row6_col5, #T_06b7b_row6_col6, #T_06b7b_row6_col19, #T_06b7b_row6_col20, #T_06b7b_row6_col21, #T_06b7b_row6_col22, #T_06b7b_row6_col23, #T_06b7b_row6_col24, #T_06b7b_row6_col25, #T_06b7b_row6_col26, #T_06b7b_row6_col27, #T_06b7b_row7_col0, #T_06b7b_row7_col1, #T_06b7b_row7_col2, #T_06b7b_row7_col3, #T_06b7b_row7_col4, #T_06b7b_row7_col19, #T_06b7b_row7_col20, #T_06b7b_row7_col21, #T_06b7b_row7_col22, #T_06b7b_row7_col23, #T_06b7b_row7_col24, #T_06b7b_row7_col25, #T_06b7b_row7_col26, #T_06b7b_row7_col27, #T_06b7b_row8_col0, #T_06b7b_row8_col1, #T_06b7b_row8_col2, #T_06b7b_row8_col3, #T_06b7b_row8_col4, #T_06b7b_row8_col10, #T ...

# %% [markdown]
# ## Baseline model
# #### First we create a baseline model (without any Machine learning). The baseline is just the pixel similarity of an image to the average of each numbers training dataset.

# %%
# Get all images for a specific number
# Convert them into tensors and normalize them to 1
# Stack all those tensors
# Repeat for all numbers and the create a list of all stacks

number_stacks = [torch.stack([tensor(Image.open(zpath)).float()/255 for zpath in number_list[i]]) for i in range(10)]

[stacked_num.shape for stacked_num in number_stacks]
# Out:
# [torch.Size([5923, 28, 28]),
#  torch.Size([6742, 28, 28]),
#  torch.Size([5958, 28, 28]),
#  torch.Size([6131, 28, 28]),
#  torch.Size([5842, 28, 28]),
#  torch.Size([5421, 28, 28]),
#  torch.Size([5918, 28, 28]),
#  torch.Size([6265, 28, 28]),
#  torch.Size([5851, 28, 28]),
#  torch.Size([5949, 28, 28])]

# %% [markdown]
# #### Calculate the mean of each and show as an image

# %%
mean = [stacked_num.mean(0) for stacked_num in number_stacks]
for i in range(10):
    show_image(mean[i])

# %% [markdown]
# #### Try the loss for some number

# %%
for i in range(10):
    dist_abs = (number_stacks[3][1] - mean[i]).abs().mean()
    dist_sqr = ((number_stacks[3][1] - mean[i])**2).mean().sqrt()
    print("Abs. distance to " + str(i) + ":", dist_abs)
    print("Sqr. distance to " + str(i) + ":", dist_sqr)
# Out:
# Abs. distance to 0: tensor(0.1879)
# Sqr. distance to 0: tensor(0.3203)
# Abs. distance to 1: tensor(0.1353)
# Sqr. distance to 1: tensor(0.2996)
# Abs. distance to 2: tensor(0.1734)
# Sqr. distance to 2: tensor(0.3023)
# Abs. distance to 3: tensor(0.1114)
# Sqr. distance to 3: tensor(0.2021)
# Abs. distance to 4: tensor(0.1704)
# Sqr. distance to 4: tensor(0.3142)
# Abs. distance to 5: tensor(0.1443)
# Sqr. distance to 5: tensor(0.2577)
# Abs. distance to 6: tensor(0.1723)
# Sqr. distance to 6: tensor(0.3103)
# Abs. distance to 7: tensor(0.1586)
# Sqr. distance to 7: tensor(0.3021)
# Abs. distance to 8: tensor(0.1550)
# Sqr. distance to 8: tensor(0.2791)
# Abs. distance to 9: tensor(0.1601)
# Sqr. distance to 9: tensor(0.3013)

# %% [markdown]
# #### More elegant version using pytorch

# %%
dist_abs = tensor([F.l1_loss(number_stacks[3][1], mean_num) for mean_num in mean])
dist_sqr = tensor([F.mse_loss(number_stacks[3][1], mean_num).sqrt() for mean_num in mean])
torch.argmin(dist_abs), torch.argmin(dist_sqr)
# Out:
# (tensor(3), tensor(3))

# %% [markdown]
# #### Define a metric and an identifier function

# %%
def l1_dist(a,b): return (a-b).abs().mean((-1,-2))

def l2_dist(a,b): return ((a-b)**2).mean((-1,-2)).sqrt()

def identify_abs(img):
    d_abs = torch.stack([l1_dist(img, mean_num) for mean_num in mean])
    return torch.min(d_abs, dim=0)[1], torch.min(d_abs, dim=0)[0]

def identify_sqr(img):
    d_sqr = torch.stack([l2_dist(img, mean_num) for mean_num in mean])
    return torch.min(d_sqr, dim=0)[1], torch.min(d_sqr, dim=0)[0]

def is_num_abs(img, number):
    return torch.eq(identify_abs(img)[0], number)

def is_num_sqr(img, number):
    return torch.eq(identify_sqr(img)[0], number)

# %% [markdown]
# #### Prepare validation Images

# %%
vnumber_stacks = [torch.stack([tensor(Image.open(zpath)).float()/255 for zpath in vnumber_list[i]]) for i in range(10)]
[stacked_num.shape for stacked_num in vnumber_stacks]
# Out:
# [torch.Size([980, 28, 28]),
#  torch.Size([1135, 28, 28]),
#  torch.Size([1032, 28, 28]),
#  torch.Size([1010, 28, 28]),
#  torch.Size([982, 28, 28]),
#  torch.Size([892, 28, 28]),
#  torch.Size([958, 28, 28]),
#  torch.Size([1028, 28, 28]),
#  torch.Size([974, 28, 28]),
#  torch.Size([1009, 28, 28])]

# %% [markdown]
# #### Test validation Images

# %%
accuracy_abs = torch.stack([is_num_abs(vnumber_stacks[i], i).float().mean() for i in range(10)])
accuracy_sqr = torch.stack([is_num_sqr(vnumber_stacks[i], i).float().mean() for i in range(10)])
for i in range(10):
    print("Accuracy for " + str(i) +"s: ", accuracy_abs[i], " (abs),     ", accuracy_sqr[i], " (sqr)")
print("Accuracy overall: ", accuracy_abs.mean(), " (abs),     ", accuracy_sqr.mean(), " (sqr)")
# Out:
# Accuracy for 0s:  tensor(0.8153)  (abs),      tensor(0.8959)  (sqr)
# Accuracy for 1s:  tensor(0.9982)  (abs),      tensor(0.9621)  (sqr)
# Accuracy for 2s:  tensor(0.4234)  (abs),      tensor(0.7568)  (sqr)
# Accuracy for 3s:  tensor(0.6089)  (abs),      tensor(0.8059)  (sqr)
# Accuracy for 4s:  tensor(0.6680)  (abs),      tensor(0.8259)  (sqr)
# Accuracy for 5s:  tensor(0.3262)  (abs),      tensor(0.6861)  (sqr)
# Accuracy for 6s:  tensor(0.7871)  (abs),      tensor(0.8633)  (sqr)
# Accuracy for 7s:  tensor(0.7646)  (abs),      tensor(0.8327)  (sqr)
# Accuracy for 8s:  tensor(0.4425)  (abs),      tensor(0.7372)  (sqr)
# Accuracy for 9s:  tensor(0.7760)  (abs),      tensor(0.8067)  (sqr)
# Accuracy overall:  tensor(0.6610)  (abs),      tensor(0.8173)  (sqr)

# %% [markdown]
# ## From scratch Neural Network

# %% [markdown]
# ### Step 0: preparing the data

# %% [markdown]
# Preparing the data:
# Create a rank 2 tensor x with a vector of all pixels for each image and a rank 1 (technically rank 2) tensor y with the category for each image, then zip the into a Dataset usable by PyTorch.

# %%
train_x = torch.cat(number_stacks).view(-1,28*28)
train_y = torch.cat([tensor([i]*len(number_stacks[i])) for i in range(10)])
dset = list(zip(train_x, train_y))
train_x.shape, train_y.shape
# Out:
# (torch.Size([60000, 784]), torch.Size([60000]))

# %% [markdown]
# Repeat for the validation set

# %%
valid_x = torch.cat(vnumber_stacks).view(-1,28*28)
valid_y = torch.cat([tensor([i]*len(vnumber_stacks[i])) for i in range(10)])
valid_dset = list(zip(valid_x, valid_y))

# %% [markdown]
# ### Neural Network definition
#
# Initialize weights and biases

# %%
def init_params(size, std=1.0):
    return (torch.randn(size)*std).requires_grad_()

w1 = init_params((28*28,30))
b1 = init_params(30)
w2 = init_params((30, 10))
b2 = init_params(10)

# %% [markdown]
# First layer with 30 outputs
#
# Take the ReLU of them -> Nonlinearity
#
# Second layer with 10 outputs -> one for each possible category

# %%
def simple_net(xb):
    res = xb@w1 + b1
    res = res.max(tensor(0.0))
    res = res@w2 + b2
    return res

# %% [markdown]
# ### Loss function

# %%
def softmax(x):
    return torch.exp(x) / torch.exp(x).sum(dim=1, keepdim=True)

# %%
def neg_log_smloss(sm_acts):
    torch.log(sm_acts)
    ret = [-sm_acts[i, train_y[i]] for i in range(len(train_y))]
    return tensor(ret)

# %%
sm = torch.softmax(simple_net(train_x),dim=1)
sm[0]
# Out:
# tensor([7.6654e-18, 1.0443e-33, 8.3852e-13, 9.8986e-26, 9.9906e-01, 2.2421e-44, 0.0000e+00, 3.5467e-11, 9.3508e-04, 3.2617e-10], grad_fn=<SelectBackward0>)

# %%
loss_func = nn.CrossEntropyLoss()
loss_func(simple_net(train_x), train_y)
# Out:
# tensor(60.6068, grad_fn=<NllLossBackward0>)

# %% [markdown]
# ### Training

# %%
dl = DataLoader(dset, batch_size = 2048)
valid_dl = DataLoader(valid_dset, batch_size=2048)
xb, yb = first(dl)
xb.shape, yb.shape
# Out:
# (torch.Size([2048, 784]), torch.Size([2048]))

# %%
def calc_grad(xb, yb, model):
    preds = model(xb)
    loss = loss_func(preds, yb)
    loss.sum().backward()

def train_epoch(model, lr, params):
    for xb, yb in dl:
        calc_grad(xb, yb, model)
        for p in params:
            p.data -= p.grad*lr
            p.grad.data.zero_()

def batch_accuracy(xb, yb):
    preds = torch.softmax(xb,dim=1)
    correct = torch.eq(torch.max(preds, dim=1)[1], yb)
    return correct.float().mean()

def validate_epoch(model):
    accs = [batch_accuracy(model(xb), yb) for xb,yb in valid_dl]
    return round(torch.stack(accs).mean().item(), 14)

# %%
validate_epoch(simple_net)
# Out:
# 0.13320484757423

# %%
lr = 0.25
params = w1,b1,w2,b2
dls = DataLoaders(dl, valid_dl)
learn = Learner(dls, nn.Linear(28*28,10), opt_func=SGD,
                loss_func=loss_func, metrics=batch_accuracy)

# %%
#learn.fit(40, 0.1)

# %%
simple_net_pt = nn.Sequential(
    nn.Linear(28*28,10000),
    nn.ReLU(),
    #nn.Linear(20,20),
    #nn.ReLU(),
    nn.Linear(10000,10)
)

# %%
learn = Learner(dls, simple_net_pt, opt_func=SGD,
                loss_func=loss_func, metrics=batch_accuracy)

learn.fit(100, 0.25)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>batch_accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.032501</td>
#       <td>4.647899</td>
#       <td>0.101600</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.427047</td>
#       <td>2.692341</td>
#       <td>0.223200</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.015208</td>
#       <td>2.130095</td>
#       <td>0.365600</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.781385</td>
#       <td>1.809144</td>
#       <td>0.438300</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.646343</td>
#       <td>1.597564</td>
#       <td>0.478200</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.563505</td>
#       <td>1.411030</td>
#       <td>0.514200</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.510067</td>
#       <td>1.253249</td>
#       <td>0.550500</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.471857</td>
#       <td>1.108827</td>
#       <td>0.585800</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.441397</td>
#       <td>0.980537</td>
#       <td>0.626100</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.415324</td>
#       <td>0.867717</td>
#       <td>0.662700</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.391204</td>
#       <td>0.776973</td>
#       <td>0.698600</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.368739</td>
#       <td>0.695177</td>
#       <td>0.731400</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.347357</td>
#       <td>0.628633</td>
#       <td>0.758300</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.327080</td>
#       <td>0.573609</td>
#       <td>0.781100</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.308114</td>
#       <td>0.527529</td>
#       <td>0.801400</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.290539</td>
#       <td>0.488651</td>
#       <td>0.817900</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.274387</td>
#       <td>0.455503</td>
#       <td>0.832900</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.259724</td>
#       <td>0.426590</td>
#       <td>0.845000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.246452</td>
#       <td>0.401634</td>
#       <td>0.856200</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.234511</td>
#       <td>0.379370</td>
#       <td>0.865000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.223737</td>
#       <td>0.359751</td>
#       <td>0.873900</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.213987</td>
#       <td>0.342142</td>
#       <td>0.880600</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.205132</td>
#       <td>0.326400</td>
#       <td>0.885900</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.197083</td>
#       <td>0.312078</td>
#       <td>0.891800</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.189725</td>
#       <td>0.299045</td>
#       <td>0.896500</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.182981</td>
#       <td>0.287104</td>
#       <td>0.901000</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.176770</td>
#       <td>0.276258</td>
#       <td>0.904700</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.171036</td>
#       <td>0.266222</td>
#       <td>0.908500</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.165715</td>
#       <td>0.256980</td>
#       <td>0.911600</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.160757</td>
#       <td>0.248438</td>
#       <td>0.914400</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.156126</td>
#       <td>0.240483</td>
#       <td>0.917300</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.151781</td>
#       <td>0.233130</td>
#       <td>0.920100</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.147697</td>
#       <td>0.226290</td>
#       <td>0.921900</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.143854</td>
#       <td>0.219864</td>
#       <td>0.924700</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.140228</td>
#       <td>0.213840</td>
#       <td>0.927300</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.136792</td>
#       <td>0.208187</td>
#       <td>0.929400</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.133538</td>
#       <td>0.202848</td>
#       <td>0.931300</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.130441</td>
#       <td>0.197825</td>
#       <td>0.933200</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.127491</td>
#       <td>0.193105</td>
#       <td>0.934400</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>0.124677</td>
#       <td>0.188617</td>
#       <td>0.935600</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.121994</td>
#       <td>0.184372</td>
#       <td>0.937100</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.119423</td>
#       <td>0.180330</td>
#       <td>0.938900</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.116959</td>
#       <td>0.176531</td>
#       <td>0.940600</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>0.114597</td>
#       <td>0.172902</td>
#       <td>0.941200</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>0.112329</td>
#       <td>0.169439</td>
#       <td>0.942900</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.110146</td>
#       <td>0.166151</td>
#       <td>0.944800</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.108044</td>
#       <td>0.163028</td>
#       <td>0.946300</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>0.106018</td>
#       <td>0.160009</td>
#       <td>0.947300</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>0.104061</td>
#       <td>0.157165</td>
#       <td>0.948100</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>0.102176</td>
#       <td>0.154435</td>
#       <td>0.949000</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.100355</td>
#       <td>0.151803</td>
#       <td>0.950300</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.098594</td>
#       <td>0.149296</td>
#       <td>0.951300</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.096892</td>
#       <td>0.146881</td>
#       <td>0.952000</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.095243</td>
#       <td>0.144582</td>
#       <td>0.952400</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.093647</td>
#       <td>0.142359</td>
#       <td>0.953200</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.092101</td>
#       <td>0.140233</td>
#       <td>0.954000</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.090601</td>
#       <td>0.138149</td>
#       <td>0.955200</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.089143</td>
#       <td>0.136167</td>
#       <td>0.955700</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>0.087725</td>
#       <td>0.134259</td>
#       <td>0.956700</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.086346</td>
#       <td>0.132416</td>
#       <td>0.957300</td>

# %%
x,y = dls.one_batch()
preds,_ = learn.get_preds(dl=[(x,y)])
print(y[-1])
torch.softmax(preds[-1],dim=-1)
# Out:
# tensor(0)
# tensor([9.9993e-01, 6.7038e-07, 5.3819e-06, 7.0435e-08, 7.9705e-08, 6.6642e-06, 1.0869e-05, 4.7122e-05, 1.4007e-07, 1.2116e-06])

# %%
learn.export()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_6063/1466232964.py in <module>
# ----> 1 learn.export()
#
# ~/.local/lib/python3.8/site-packages/fastai/learner.py in export(self, fname, pickle_module, pickle_protocol)
#     367     self._end_cleanup()
#     368     old_dbunch = self.dls
# --> 369     self.dls = self.dls.new_empty()
#     370     state = self.opt.state_dict() if self.opt is not None else None
#     371     self.opt = None
#
# ~/.local/lib/python3.8/site-packages/fastai/data/core.py in new_empty(self)
#     144     def __getitem__(self, i): return self.loaders[i]
#     145     def new_empty(self):
# --> 146         loaders = [dl.new(dl.dataset.new_empty()) for dl in self.loaders]
#     147         return type(self)(*loaders, path=self.path, device=self.device)
#     148
#
# ~/.local/lib/python3.8/site-packages/fastai/data/core.py in <listcomp>(.0)
#     144     def __getitem__(self, i): return self.loaders[i]
#     145     def new_empty(self):
# --> 146         loaders = [dl.new(dl.dataset.new_empty()) for dl in self.loaders]
#     147         return type(self)(*loaders, path=self.path, device=self.device)
#     148
#
# AttributeError: 'list' object has no attribute 'new_empty'

# %% [markdown]
# ## PyTorch / FastAI Neural Network
